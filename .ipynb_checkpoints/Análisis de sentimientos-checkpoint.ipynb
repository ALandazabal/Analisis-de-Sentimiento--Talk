# %% [markdown]
# # Applying sentiment analysis to your social network

# %% [markdown]
# # Español

# %% [markdown]
# ## Step 1: Extract Data

# %%
import tweepy
from tweepy import OAuthHandler
import csv
from textblob import TextBlob

import twitterCredentials

# %%
api_key = twitterCredentials.api_key
api_secret = twitterCredentials.api_secret
access_token = twitterCredentials.access_token
access_secret = twitterCredentials.access_secret

auth = OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
timeline = api.user_timeline(id="CNNEE", count=50 )

with open('CNNEE.csv', 'w', newline='', encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Date", "Day", "Tweet", "Retweets", "Likes"])
    
    for tweet in timeline:
        b = TextBlob(tweet.text)

        if b.detect_language() == 'es':
            print(tweet.text)
            data = [tweet.created_at.date().strftime("%b %d %Y "), tweet.created_at.date().strftime("%b %d"), tweet.text, tweet.retweet_count, tweet.favorite_count]
            writer.writerow(data)
# Out:
# #AMLO dice que se entera de la existencia de la comisión para la discriminación por la polémica con @ChumelTorres ¿… https://t.co/Vcmx9Ra0Cs
# ¿Cómo reaccionaría Estados Unidos si el Gobierno de López Obrador le vendiera gasolina a Venezuela? Compartimos el… https://t.co/gxs1WJTvdr
# Es el momento perfecto para elegir un nuevo cargador portátil o de pared, o un cargador que pueda hacer ambas cosas… https://t.co/dFqJhdUNvf
# "Por supuesto que no": eso respondió Fauci cuando le preguntaron si va a ir al evento de campaña de Trump… https://t.co/inQJ1wPyRY
# El gobierno federal de EE.UU. quedó con 63 millones de dosis de hidroxicloroquina (que no puede distribuir)… https://t.co/ZO7gfWAoMj
# Brasil reporta 32.188 casos nuevos de covid-19 en un día https://t.co/2cXnF5xDIj https://t.co/gVN8b8ibjr
# RT @cnncolombia: Carlos Lehder, considerado como uno de los principales capos del narcotráfico del mundo, quedó en libertad luego de sortea…
# La OMS asegura que 11 vacunas contra el #coronavirus están en fase de ensayos con humanos en todo el mundo. Hacemos… https://t.co/bkPfALeGTK
# ⚠️ Perú supera a Italia en número de casos confirmados de covid-19 https://t.co/Q1sixQsGAK https://t.co/dIsLRvP36S
# "No se muevan. No se muevan. Solo relájense. Nadie está herido. ¡Por favor! No quiero herir a ninguno".… https://t.co/q8OP2EBu7W
# Según el extracto publicado en el diario, después de que Xi se mostrara dispuesto a reabrir las discusiones comerci… https://t.co/rthDnH9WAJ
# ¿Qué dicen ambos países sobre el incidente? ¿Cuál es el origen de este esté conflicto? José Levy nos explica los de… https://t.co/Et7WVSKuF7
# El gobernador de Nueva York, Andrew Coumo, descartó buscar la candidatura presidencial del Partido Demócrata. Esto… https://t.co/fPHefNvFCy
# La 23 veces campeona de torneos de Grand Slam dijo que estaba ansiosa por llegar a la cancha en Nueva York. https://t.co/5kY1k6auGl
# AMLO aseguró que que se enteró de la existencia de la Conapred debido a la polémica que se generó por la cancelació… https://t.co/q0Vb0OxR55
# Tenemos que ser el cambio de EE.UU., dice manifestante negro adoptado por familia mexicana. https://t.co/0x5jpohx16
# ¿Recuerdas a Spot, el perro robot que ha sido sensación por internet en años? Ahora lo puedes comprar.
# https://t.co/I8AlPIalDS
# No sé cuando voy a poder regresar a mi país, dice peruana varada en Italia. Escasez de dinero y un lugar donde qued… https://t.co/jBVrdun9jK
# RT @deportescnn: Estos son los detalles del formato de la Liga de Campeones para culminar el torneo...
# https://t.co/Nk5oEGQh39
# 🎧 #Podcast • ¿Es la dexametasuna una esperanza real para pacientes graves con #coronavirus? El @drhuerta lo analiza… https://t.co/58xGW2rJmt
# La evolución del racismo a veces es sutil, pero no por eso deja de ser dañino. Mira lo que tiene que decir al respe… https://t.co/N00MFl2Zd1
# Ministerio de Justicia presenta denuncia penal contra el fiscal general de Bolivia https://t.co/6RjwdLHD18
# El exasesor de seguridad nacional John Bolton afirma que el presidente Donald Trump le pidió a su homólogo chino, X… https://t.co/FHN1ajh5DM
# ¿Esperabas la nueva temporada de Fortnite? Ya llegó y estas son las novedades que debes saber:
# https://t.co/XtCxURhYk3
# La NASA lo rechazó en 11 ocasiones. Sin embargo, perseveró una y otra vez hasta que logró su sueño de convertirse e… https://t.co/ehAjTo3xq9
# El dominicano Manny Cruz le cuenta a @MarielaCNN cómo fue la invitación de Elvis Crespo para participar en "Imagina… https://t.co/t4086efYZj
# ¿Cómo se manifiesta el racismo en América Latina? Dialogamos sobre el tema con el profesor de Sociología Eduardo Bo… https://t.co/Q7esUQw8KI
# Fiscalía dice que el exagente Rolfe pateó a Rayshard Brooks "mientras estaba en el suelo, mientras estaba allí luch… https://t.co/P1LaXmHGPi
# Un exactivista evangélico habla sobre la sesión fotográfica del presidente Trump después de que la policía expulsar… https://t.co/PWPsMkQQ6b
# El fiscal explicó varias violaciones a protocolos y reglas de la ciudad, incluyendo que una de las balas impactó ve… https://t.co/Z9rNgRQiG4
# 🎧 #Podcast • Esta semana dieron a conocer los resultados preliminares de un estudio, aún no publicado, que indica q… https://t.co/LioYnVmPCr
# ÚLTIMA HORA - El fiscal de distrito del condado de Fulton, Paul Howard, anunció 11 cargos contra el exagente de Atl… https://t.co/FtUVWJ2kj1
# Esta noche en @CamiloCNN no te pierdas la entrevista con la reconocida cantante y actriz mexicana Angélica María. 9… https://t.co/YSXSRwQdFk
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~\anaconda3\lib\http\client.py in connect(self)
#     937         self.sock = self._create_connection(
# --> 938             (self.host,self.port), self.timeout, self.source_address)
#     939         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     727         try:
# --> 728             raise err
#     729         finally:
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-3-d101769becc2> in <module>
#       8         b = TextBlob(tweet.text)
#       9
# ---> 10         if b.detect_language() == 'es':
#      11             print(tweet.text)
#      12             data = [tweet.created_at.date().strftime("%b %d %Y "), tweet.created_at.date().strftime("%b %d"), tweet.text, tweet.retweet_count, tweet.favorite_count]
#
# ~\anaconda3\lib\site-packages\textblob\blob.py in detect_language(self)
#     566         :rtype: str
#     567         """
# --> 568         return self.translator.detect(self.raw)
#     569
#     570     def correct(self):
#
# ~\anaconda3\lib\site-packages\textblob\translate.py in detect(self, source, host, type_)
#      70         data = {"q": source}
#      71         url = u'{url}&sl=auto&tk={tk}'.format(url=self.url, tk=_calculate_tk(source))
# ---> 72         response = self._request(url, host=host, type_=type_, data=data)
#      73         result, language = json.loads(response)
#      74         return language
#
# ~\anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_open(self, req)
#    1345
#    1346     def http_open(self, req):
# -> 1347         return self.do_open(http.client.HTTPConnection, req)
#    1348
#    1349     http_request = AbstractHTTPHandler.do_request_
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
# -> 1321                 raise URLError(err)
#    1322             r = h.getresponse()
#    1323         except:
#
# URLError: <urlopen error [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder>

# %% [markdown]
# ###  Facebook

# %%
from facebook_scraper import get_posts

# %%
for post in get_posts('pyconcolombia', pages=1):
    print(post['text'])
# Out:
# SAT, NOV 24, 2018
# Taller de Programación para Mujeres Bogotá
# ARGENTINAENPYTHON.COM
# Taller Django Girls en Cali
# Django Girls Colombia
# April 24, 2018 at 10:00 PM ·
# ¡Queremos animar a más mujeres a dominar la web!
# Es por eso que desde Django Girls Colombia y Python Cali con el apoyo de Argentina en Python, Python Colombia y Python Software Foundation estamos organizando un taller en el cual podrás construir tu propio sitio web desde cero en un día. Además, vamos a utilizar todas las herramientas que programadores profesionales utilizan diariamente. ¡Y de una manera muy sencilla!
# Para poder participar de este taller, debes inscribirte en la página oficial del evento http://miprimeraweb.org siguiendo el enlace "¡Quiero inscribirme!" y esperar un email de confirmación el día indicado en la página del evento ya que los cupos son limitados.
# El taller es totalmente ¡GRATUITO!, anímate a disfrutar de esta oportunidad e inscríbete.
# Plazo para inscripciones hasta el 12 de Mayo.
# Aclaración: haciendo click en "Asistiré" de Facebook no es válido como inscripción al evento.
# Cualquier inquietud escríbenos a djangogirlscolombia@gmail.com ó visita nuestra página oficial del evento http://miprimeraweb.org
# Sponsors: monoku.com
# Django Girls Colombia
# April 24, 2018 at 10:00 PM ·
# ¡Queremos animar a más mujeres a dominar la web!
# Es por eso que desde Django Girls Colombia y Python Cali con el apoyo de Argentina en Python, Python Colombia y Python Software Foundation estamos organizando un taller en el cual podrás construir tu propio sitio web desde cero en un día. Además, vamos a utilizar todas las herramientas que programadores profesionales utilizan diariamente. ¡Y de una manera muy sencilla!
# Para poder participar de este taller, debes inscribirte en la página oficial del evento http://miprimeraweb.org siguiendo el enlace "¡Quiero inscribirme!" y esperar un email de confirmación el día indicado en la página del evento ya que los cupos son limitados.
# El taller es totalmente ¡GRATUITO!, anímate a disfrutar de esta oportunidad e inscríbete.
# Plazo para inscripciones hasta el 12 de Mayo.
# Aclaración: haciendo click en "Asistiré" de Facebook no es válido como inscripción al evento.
# Cualquier inquietud escríbenos a djangogirlscolombia@gmail.com ó visita nuestra página oficial del evento http://miprimeraweb.org
# Sponsors: monoku.com

# %% [markdown]
# ## Step 2: Load Data

# %%
import pandas as pd

import nltk
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize

# %matplotlib inline

# %%
datos_csv = pd.read_csv('CNNEE.csv')
datos_csv.head()
# Out:
#            Date     Day                                              Tweet  \
# 0  Jun 17 2020   Jun 17  #AMLO dice que se entera de la existencia de l...
# 1  Jun 17 2020   Jun 17  ¿Cómo reaccionaría Estados Unidos si el Gobier...
# 2  Jun 17 2020   Jun 17  Es el momento perfecto para elegir un nuevo ca...
# 3  Jun 17 2020   Jun 17  "Por supuesto que no": eso respondió Fauci cua...
# 4  Jun 17 2020   Jun 17  El gobierno federal de EE.UU. quedó con 63 mil...
#
#    Retweets  Likes
# 0         1      2
# 1         7     12
# 2         6     15
# 3        11     45
# 4        32     52

# %%
Post = ""
for data in datos_csv['Tweet']:
    Post += data
    
freq = FreqDist(word_tokenize(Post))
freq.plot(20)

# %% [markdown]
# ## Step 3: Clean Data

# %%
import emoji
import re

from nltk.corpus import stopwords
import string

# %%
stopwordList = stopwords.words("Spanish")
stopwordList
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
#  'vosotras',
#  'os',
#  'mío',
#  'mía',
#  'míos',
#  'mías',
#  'tuyo',
#  'tuya',
#  'tuyos',
#  'tuyas',
#  'suyo',
#  'suya',
#  'suyos',
#  'suyas',
#  'nuestro',
#  'nuestra',
#  'nuestros',
#  'nuestras',
#  'vuestro',
#  'vuestra',
#  'vuestros',
#  'vuestras',
#  'esos',
#  'esas',
#  'estoy',
#  'estás',
#  'está',
#  'estamos',
#  'estáis',
#  'están',
#  'esté',
#  'estés',
#  'estemos',
#  'estéis',
#  'estén',
#  'estaré',
#  'estarás',
#  'estará',
#  'estaremos',
#  'estaréis',
#  'estarán',
#  'estaría',
#  'estarías',
#  'estaríamos',
#  'estaríais',
#  'estarían',
#  'estaba',
#  'estabas',
#  'estábamos',
#  'estabais',
#  'estaban',
#  'estuve',
#  'estuviste',
#  'estuvo',
#  'estuvimos',
#  'estuvisteis',
#  'estuvieron',
#  'estuviera',
#  'estuvieras',
#  'estuviéramos',
#  'estuvierais',
#  'estuvieran',
#  'estuviese',
#  'estuvieses',
#  'estuviésemos',
#  'estuvieseis',
#  'estuviesen',
#  'estando',
#  'estado',
#  'estada',
#  'estados',
#  'estadas',
#  'estad',
#  'he',
#  'has',
#  'ha',
#  'hemos',
#  'habéis',
#  'han',
#  'haya',
#  'hayas',
#  'hayamos',
#  'hayáis',
#  'hayan',
#  'habré',
#  'habrás',
#  'habrá',
#  'habremos',
#  'habréis',
#  'habrán',
#  'habría',
#  'habrías',
#  'habríamos',
#  'habríais',
#  'habrían',
#  'había',
#  'habías',
#  'habíamos',
#  'habíais',
#  'habían',
#  'hube',
#  'hubiste',
#  'hubo',
#  'hubimos',
#  'hubisteis',
#  'hubieron',
#  'hubiera',
#  'hubieras',
#  'hubiéramos',
#  'hubierais',
#  'hubieran',
#  'hubiese',
#  'hubieses',
#  'hubiésemos',
#  'hubieseis',
#  'hubiesen',
#  'habiendo',
#  'habido',
#  'habida',
#  'habidos',
#  'habidas',
#  'soy',
#  'eres',
#  'es',
#  'somos',
#  'sois',
#  'son',
#  'sea',
#  'seas',
#  'seamos',
#  'seáis',
#  'sean',
#  'seré',
#  'serás',
#  'será',
#  'seremos',
#  'seréis',
#  'serán',
#  'sería',
#  'serías',
#  'seríamos',
#  'seríais',
#  'serían',
#  'era',
#  'eras',
#  'éramos',
#  'erais',
#  'eran',
#  'fui',
#  'fuiste',
#  'fue',
#  'fuimos',
#  'fuisteis',
#  'fueron',
#  'fuera',
#  'fueras',
#  'fuéramos',
#  'fuerais',
#  'fueran',
#  'fuese',
#  'fueses',
#  'fuésemos',
#  'fueseis',
#  'fuesen',
#  'sintiendo',
#  'sentido',
#  'sentida',
#  'sentidos',
#  'sentidas',
#  'siente',
#  'sentid',
#  'tengo',
#  'tienes',
#  'tiene',
#  'tenemos',
#  'tenéis',
#  'tienen',
#  'tenga',
#  'tengas',
#  'tengamos',
#  'tengáis',
#  'tengan',
#  'tendré',
#  'tendrás',
#  'tendrá',
#  'tendremos',
#  'tendréis',
#  'tendrán',
#  'tendría',
#  'tendrías',
#  'tendríamos',
#  'tendríais',
#  'tendrían',
#  'tenía',
#  'tenías',
#  'teníamos',
#  'teníais',
#  'tenían',
#  'tuve',
#  'tuviste',
#  'tuvo',
#  'tuvimos',
#  'tuvisteis',
#  'tuvieron',
#  'tuviera',
#  'tuvieras',
#  'tuviéramos',
#  'tuvierais',
#  'tuvieran',
#  'tuviese',
#  'tuvieses',
#  'tuviésemos',
#  'tuvieseis',
#  'tuviesen',
#  'teniendo',
#  'tenido',
#  'tenida',
#  'tenidos',
#  'tenidas',
#  'tened']

# %%
punctuationList = list(string.punctuation)
punctuationList
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
stopwordsList = stopwordList + punctuationList + ['“','”','¡','¿',"''",'``','...','→','⬥','…'] + stopwords.words("English")
stopwordsList
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
#  'vosotras',
#  'os',
#  'mío',
#  'mía',
#  'míos',
#  'mías',
#  'tuyo',
#  'tuya',
#  'tuyos',
#  'tuyas',
#  'suyo',
#  'suya',
#  'suyos',
#  'suyas',
#  'nuestro',
#  'nuestra',
#  'nuestros',
#  'nuestras',
#  'vuestro',
#  'vuestra',
#  'vuestros',
#  'vuestras',
#  'esos',
#  'esas',
#  'estoy',
#  'estás',
#  'está',
#  'estamos',
#  'estáis',
#  'están',
#  'esté',
#  'estés',
#  'estemos',
#  'estéis',
#  'estén',
#  'estaré',
#  'estarás',
#  'estará',
#  'estaremos',
#  'estaréis',
#  'estarán',
#  'estaría',
#  'estarías',
#  'estaríamos',
#  'estaríais',
#  'estarían',
#  'estaba',
#  'estabas',
#  'estábamos',
#  'estabais',
#  'estaban',
#  'estuve',
#  'estuviste',
#  'estuvo',
#  'estuvimos',
#  'estuvisteis',
#  'estuvieron',
#  'estuviera',
#  'estuvieras',
#  'estuviéramos',
#  'estuvierais',
#  'estuvieran',
#  'estuviese',
#  'estuvieses',
#  'estuviésemos',
#  'estuvieseis',
#  'estuviesen',
#  'estando',
#  'estado',
#  'estada',
#  'estados',
#  'estadas',
#  'estad',
#  'he',
#  'has',
#  'ha',
#  'hemos',
#  'habéis',
#  'han',
#  'haya',
#  'hayas',
#  'hayamos',
#  'hayáis',
#  'hayan',
#  'habré',
#  'habrás',
#  'habrá',
#  'habremos',
#  'habréis',
#  'habrán',
#  'habría',
#  'habrías',
#  'habríamos',
#  'habríais',
#  'habrían',
#  'había',
#  'habías',
#  'habíamos',
#  'habíais',
#  'habían',
#  'hube',
#  'hubiste',
#  'hubo',
#  'hubimos',
#  'hubisteis',
#  'hubieron',
#  'hubiera',
#  'hubieras',
#  'hubiéramos',
#  'hubierais',
#  'hubieran',
#  'hubiese',
#  'hubieses',
#  'hubiésemos',
#  'hubieseis',
#  'hubiesen',
#  'habiendo',
#  'habido',
#  'habida',
#  'habidos',
#  'habidas',
#  'soy',
#  'eres',
#  'es',
#  'somos',
#  'sois',
#  'son',
#  'sea',
#  'seas',
#  'seamos',
#  'seáis',
#  'sean',
#  'seré',
#  'serás',
#  'será',
#  'seremos',
#  'seréis',
#  'serán',
#  'sería',
#  'serías',
#  'seríamos',
#  'seríais',
#  'serían',
#  'era',
#  'eras',
#  'éramos',
#  'erais',
#  'eran',
#  'fui',
#  'fuiste',
#  'fue',
#  'fuimos',
#  'fuisteis',
#  'fueron',
#  'fuera',
#  'fueras',
#  'fuéramos',
#  'fuerais',
#  'fueran',
#  'fuese',
#  'fueses',
#  'fuésemos',
#  'fueseis',
#  'fuesen',
#  'sintiendo',
#  'sentido',
#  'sentida',
#  'sentidos',
#  'sentidas',
#  'siente',
#  'sentid',
#  'tengo',
#  'tienes',
#  'tiene',
#  'tenemos',
#  'tenéis',
#  'tienen',
#  'tenga',
#  'tengas',
#  'tengamos',
#  'tengáis',
#  'tengan',
#  'tendré',
#  'tendrás',
#  'tendrá',
#  'tendremos',
#  'tendréis',
#  'tendrán',
#  'tendría',
#  'tendrías',
#  'tendríamos',
#  'tendríais',
#  'tendrían',
#  'tenía',
#  'tenías',
#  'teníamos',
#  'teníais',
#  'tenían',
#  'tuve',
#  'tuviste',
#  'tuvo',
#  'tuvimos',
#  'tuvisteis',
#  'tuvieron',
#  'tuviera',
#  'tuvieras',
#  'tuviéramos',
#  'tuvierais',
#  'tuvieran',
#  'tuviese',
#  'tuvieses',
#  'tuviésemos',
#  'tuvieseis',
#  'tuviesen',
#  'teniendo',
#  'tenido',
#  'tenida',
#  'tenidos',
#  'tenidas',
#  'tened',
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~',
#  '“',
#  '”',
#  '¡',
#  '¿',
#  "''",
#  '``',
#  '...',
#  '→',
#  '⬥',
#  '…',
#  'i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
Post
# Out:
# '#AMLO dice que se entera de la existencia de la comisión para la discriminación por la polémica con @ChumelTorres ¿… https://t.co/Vcmx9Ra0Cs¿Cómo reaccionaría Estados Unidos si el Gobierno de López Obrador le vendiera gasolina a Venezuela? Compartimos el… https://t.co/gxs1WJTvdrEs el momento perfecto para elegir un nuevo cargador portátil o de pared, o un cargador que pueda hacer ambas cosas… https://t.co/dFqJhdUNvf"Por supuesto que no": eso respondió Fauci cuando le preguntaron si va a ir al evento de campaña de Trump… https://t.co/inQJ1wPyRYEl gobierno federal de EE.UU. quedó con 63 millones de dosis de hidroxicloroquina (que no puede distribuir)… https://t.co/ZO7gfWAoMjBrasil reporta 32.188 casos nuevos de covid-19 en un día https://t.co/2cXnF5xDIj https://t.co/gVN8b8ibjrRT @cnncolombia: Carlos Lehder, considerado como uno de los principales capos del narcotráfico del mundo, quedó en libertad luego de sortea…La OMS asegura que 11 vacunas contra el #coronavirus están en fase de ensayos con humanos en todo el mundo. Hacemos… https://t.co/bkPfALeGTK⚠️ Perú supera a Italia en número de casos confirmados de covid-19 https://t.co/Q1sixQsGAK https://t.co/dIsLRvP36S"No se muevan. No se muevan. Solo relájense. Nadie está herido. ¡Por favor! No quiero herir a ninguno".… https://t.co/q8OP2EBu7WSegún el extracto publicado en el diario, después de que Xi se mostrara dispuesto a reabrir las discusiones comerci… https://t.co/rthDnH9WAJ¿Qué dicen ambos países sobre el incidente? ¿Cuál es el origen de este esté conflicto? José Levy nos explica los de… https://t.co/Et7WVSKuF7El gobernador de Nueva York, Andrew Coumo, descartó buscar la candidatura presidencial del Partido Demócrata. Esto… https://t.co/fPHefNvFCyLa 23 veces campeona de torneos de Grand Slam dijo que estaba ansiosa por llegar a la cancha en Nueva York. https://t.co/5kY1k6auGlAMLO aseguró que que se enteró de la existencia de la Conapred debido a la polémica que se generó
    tweet = re.sub(r'@[a-zA-Z0-9-_.]+', '', text)
    tweet = re.sub(r'#[a-zA-Z0-9-_.]+', '', tweet)
    tweet = re.sub(r'//[a-zA-Z0-9-_.]+', '', tweet)
    tweet = re.sub(r'https://[a-zA-Z0-9-_./]+', '', tweet)
    tweet = re.sub(r'https:[a-zA-Z0-9-_./]+', '', tweet)
    tweet = re.sub(r'www.[a-zA-Z0-9-_./]+', '', tweet)
    tweet = re.sub(r'[a-zA-Z0-9-./]+[…]', '', tweet)
    tweet = re.sub(r'[ ]+[…]', '', tweet)
    tweet = re.sub('\n|\r', '', tweet)
    tweet = re.sub(r'[á|ä|â|à]', 'a', tweet)
    tweet = re.sub(r'[é|ê|è]', 'e', tweet)
    tweet = re.sub(r'[í|î|ì]', 'i', tweet)
    tweet = re.sub(r'[ó|ô|ò]', 'o', tweet)
    tweet = re.sub(r'[ú|û|ù|ü]', 'u', tweet)
    tweet = re.sub(r'RT ', '', tweet)
    return tweet

# %%
tweets_clean = clean_tweets_regex(tweets_clean_emoji)
tweets_clean
# Out:
# ' dice que se entera de la existencia de la comision para la discriminacion por la polemica con  ¿… ¿Como reaccionaria Estados Unidos si el Gobierno de Lopez Obrador le vendiera gasolina a Venezuela? Compartimos   el momento perfecto para elegir un nuevo cargador portatil o de pared, o un cargador que pueda hacer ambas  "Por supuesto que no": eso respondio Fauci cuando le preguntaron si va a ir al evento de campaña de   gobierno federal de EE.UU. quedo con 63 millones de dosis de hidroxicloroquina (que no puede distribuir)…  reporta 32.188 casos nuevos de covid-19 en un dia   : Carlos Lehder, considerado como uno de los principales capos del narcotrafico del mundo, quedo en libertad luego de La OMS asegura que 11 vacunas contra el  estan en fase de ensayos con humanos en todo el mundo.  Peru supera a Italia en numero de casos confirmados de covid-19  "No se muevan. No se muevan. Solo relajense. Nadie esta herido. ¡Por favor! No quiero herir a ninguno" un el extracto publicado en el diario, despues de que Xi se mostrara dispuesto a reabrir las discusiones  ¿Que dicen ambos paises sobre el incidente? ¿Cual es el origen de este este conflicto? Jose Levy nos explica los   gobernador de Nueva York, Andrew Coumo, descarto buscar la candidatura presidencial del Partido Democrata.   23 veces campeona de torneos de Grand Slam dijo que estaba ansiosa por llegar a la cancha en Nueva York.  aseguro que que se entero de la existencia de la Conapred debido a la polemica que se genero por la cancelacio…  que ser el cambio de EE.UU., dice manifestante negro adoptado por familia mexicana. ¿Recuerdas a Spot, el perro robot que ha sido sensacion por internet en años? Ahora lo puedes comprar.  se cuando voy a poder regresar a mi pais, dice peruana varada en Italia. Escasez de dinero y un lugar donde   : Estos son los detalles del formato de la Liga de Campeones para culminar el torneo...  • ¿Es la dexametasuna una esperanza real para pacientes graves con ? El  lo   evolucion del racismo a veces es sutil, pero no por eso deja de ser dañino. Mira lo que tiene que decir al   de Justicia presenta denuncia penal contra el fiscal general de Bolivia  exasesor de seguridad nacional John Bolton afirma que el presidente Donald Trump le pidio a su homologo chino,  ¿Esperabas la nueva temporada de Fortnite? Ya llego y estas son las novedades que debes saber:  NASA lo rechazo en 11 ocasiones. Sin embargo, persevero una y otra vez hasta que logro su sueño de convertirse   dominicano Manny Cruz le cuenta a  como fue la invitacion de Elvis Crespo para participar en " ¿Como se manifiesta el racismo en America Latina? Dialogamos sobre el tema con el profesor de Sociologia Eduardo  ia dice que el exagente Rolfe pateo a Rayshard Brooks "mientras estaba en el suelo, mientras estaba alli   exactivista evangelico habla sobre la sesion fotografica del presidente Trump despues de que la policia   fiscal explico varias violaciones a protocolos y reglas de la ciudad, incluyendo que una de las balas impacto   • Esta semana dieron a conocer los resultados preliminares de un estudio, aun no publicado, que indica  ÚLTIMA HORA - El fiscal de distrito del condado de Fulton, Paul Howard, anuncio 11 cargos contra el exagente de   noche en  no te pierdas la entrevista con la reconocida cantante y actriz mexicana Angelica Maria.  '

# %%
filtro = [palabra for palabra in word_tokenize(tweets_clean) if palabra not in stopwordsList]
filtro
# Out:
# ['dice',
#  'entera',
#  'existencia',
#  'comision',
#  'discriminacion',
#  'polemica',
#  '¿…',
#  '¿Como',
#  'reaccionaria',
#  'Estados',
#  'Unidos',
#  'si',
#  'Gobierno',
#  'Lopez',
#  'Obrador',
#  'vendiera',
#  'gasolina',
#  'Venezuela',
#  'Compartimos',
#  'momento',
#  'perfecto',
#  'elegir',
#  'nuevo',
#  'cargador',
#  'portatil',
#  'pared',
#  'cargador',
#  'pueda',
#  'hacer',
#  'ambas',
#  'Por',
#  'supuesto',
#  'respondio',
#  'Fauci',
#  'preguntaron',
#  'si',
#  'va',
#  'ir',
#  'evento',
#  'campaña',
#  'gobierno',
#  'federal',
#  'EE.UU',
#  'quedo',
#  '63',
#  'millones',
#  'dosis',
#  'hidroxicloroquina',
#  'puede',
#  'distribuir',
#  'reporta',
#  '32.188',
#  'casos',
#  'nuevos',
#  'covid-19',
#  'dia',
#  'Carlos',
#  'Lehder',
#  'considerado',
#  'principales',
#  'capos',
#  'narcotrafico',
#  'mundo',
#  'quedo',
#  'libertad',
#  'luego',
#  'La',
#  'OMS',
#  'asegura',
#  '11',
#  'vacunas',
#  'estan',
#  'fase',
#  'ensayos',
#  'humanos',
#  'mundo',
#  'Peru',
#  'supera',
#  'Italia',
#  'numero',
#  'casos',
#  'confirmados',
#  'covid-19',
#  'No',
#  'muevan',
#  'No',
#  'muevan',
#  'Solo',
#  'relajense',
#  'Nadie',
#  'herido',
#  '¡Por',
#  'favor',
#  'No',
#  'quiero',
#  'herir',
#  'ninguno',
#  'extracto',
#  'publicado',
#  'diario',
#  'despues',
#  'Xi',
#  'mostrara',
#  'dispuesto',
#  'reabrir',
#  'discusiones',
#  '¿Que',
#  'dicen',
#  'ambos',
#  'paises',
#  'incidente',
#  '¿Cual',
#  'origen',
#  'conflicto',
#  'Jose',
#  'Levy',
#  'explica',
#  'gobernador',
#  'Nueva',
#  'York',
#  'Andrew',
#  'Coumo',
#  'descarto',
#  'buscar',
#  'candidatura',
#  'presidencial',
#  'Partido',
#  'Democrata',
#  '23',
#  'veces',
#  'campeona',
#  'torneos',
#  'Grand',
#  'Slam',
#  'dijo',
#  'ansiosa',
#  'llegar',
#  'cancha',
#  'Nueva',
#  'York',
#  'aseguro',
#  'entero',
#  'existencia',
#  'Conapred',
#  'debido',
#  'polemica',
#  'genero',
#  'cancelacio…',
#  'ser',
#  'cambio',
#  'EE.UU.',
#  'dice',
#  'manifestante',
#  'negro',
#  'adoptado',
#  'familia',
#  'mexicana',
#  '¿Recuerdas',
#  'Spot',
#  'perro',
#  'robot',
#  'sido',
#  'sensacion',
#  'internet',
#  'años',
#  'Ahora',
#  'puedes',
#  'comprar',
#  'voy',
#  'poder',
#  'regresar',
#  'pais',
#  'dice',
#  'peruana',
#  'varada',
#  'Italia',
#  'Escasez',
#  'dinero',
#  'lugar',
#  'Estos',
#  'detalles',
#  'formato',
#  'Liga',
#  'Campeones',
#  'culminar',
#  'torneo',
#  '•',
#  '¿Es',
#  'dexametasuna',
#  'esperanza',
#  'real',
#  'pacientes',
#  'graves',
#  'El',
#  'evolucion',
#  'racismo',
#  'veces',
#  'sutil',
#  'deja',
#  'ser',
#  'dañino',
#  'Mira',
#  'decir',
#  'Justicia',
#  'presenta',
#  'denuncia',
#  'penal',
#  'fiscal',
#  'general',
#  'Bolivia',
#  'exasesor',
#  'seguridad',
#  'nacional',
#  'John',
#  'Bolton',
#  'afirma',
#  'presidente',
#  'Donald',
#  'Trump',
#  'pidio',
#  'homologo',
#  'chino',
#  '¿Esperabas',
#  'nueva',
#  'temporada',
#  'Fortnite',
#  'Ya',
#  'llego',
#  'novedades',
#  'debes',
#  'saber',
#  'NASA',
#  'rechazo',
#  '11',
#  'ocasiones',
#  'Sin',
#  'embargo',
#  'persevero',
#  'vez',
#  'logro',
#  'sueño',
#  'convertirse',
#  'dominicano',
#  'Manny',
#  'Cruz',
#  'cuenta',
#  'invitacion',
#  'Elvis',
#  'Crespo',
#  'participar',
#  '¿Como',
#  'manifiesta',
#  'racismo',
#  'America',
#  'Latina',
#  'Dialogamos',
#  'tema',
#  'profesor',
#  'Sociologia',
#  'Eduardo',
#  'ia',
#  'dice',
#  'exagente',
#  'Rolfe',
#  'pateo',
#  'Rayshard',
#  'Brooks',
#  'mientras',
#  'suelo',
#  'mientras',
#  'alli',
#  'exactivista',
#  'evangelico',
#  'habla',
#  'sesion',
#  'fotografica',
#  'presidente',
#  'Trump',
#  'despues',
#  'policia',
#  'fiscal',
#  'explico',
#  'varias',
#  'violaciones',
#  'protocolos',
#  'reglas',
#  'ciudad',
#  'incluyendo',
#  'balas',
#  'impacto',
#  '•',
#  'Esta',
#  'semana',
#  'dieron',
#  'conocer',
#  'resultados',
#  'preliminares',
#  'estudio',
#  'aun',
#  'publicado',
#  'indica',
#  'ÚLTIMA',
#  'HORA',
#  'El',
#  'fiscal',
#  'distrito',
#  'condado',
#  'Fulton',
#  'Paul',
#  'Howard',
#  'anuncio',
#  '11',
#  'cargos',
#  'exagente',
#  'noche',
#  'pierdas',
#  'entrevista',
#  'reconocida',
#  'cantante',
#  'actriz',
#  'mexicana',
#  'Angelica',
#  'Maria']

# %%
freq = FreqDist(filtro)
freq.plot(20)

# %% [markdown]
# ## Step 4: Process Data

# %%
from nltk.classify import NaiveBayesClassifier

# %%
datos_excel = pd.read_excel(open('taggedTweets.xlsx','rb'))
datos_excel = pd.DataFrame(datos_excel)
sample = datos_excel.sample(len(datos_excel))
sample
# Out:
#                                                   Tweet  Retweets  Favoritos  \
# 839   RT @AClimatica: Desde el @aulaviva apoyamos ac...        13          0
# 218   RT @ula_tv: El Rectorado de la Universidad de ...         8          0
# 105   Las Autoridades y comunidad de la UCLA lamenta...         1          1
# 1027  #FelizLunes #13May continúa el proceso de insc...         1          1
# 440   #UPEL Informa que las actividades académicas y...         6          2
# ...                                                 ...       ...        ...
# 604   Información importante del Centro Local Aragua...         5          6
# 226   RT @UCarabobo: La rectora @jessydivo y demás a...         7          0
# 196   #FrasesUCV_Noticias No he fracasado. He encon...         5         14
# 1172  RT @QuintadeAnauco: “…Porque la música, tú sab...         5          0
# 1215  RT @ceofanb: Bolívar “Gral José Laurencio Silv...       258          0
#
#      Sentimiento
# 839          neu
# 218          neg
# 105          neg
# 1027         pos
# 440          neg
# ...          ...
# 604          neu
# 226          neg
# 196          neg
# 1172         pos
# 1215         pos
#
# [1362 rows x 4 columns]

# %%
def construirBolsaDePalabras(tweets):
    diccionario={}
    for palabra in word_tokenize(tweets):
        if palabra not in stopwordsList:
            diccionario[palabra]=1
    return diccionario

# %%
rasgosNegativos = []
rasgosPositivos = []
rasgosNeutrales = []
    
for indice_fila, fila in sample.iterrows():
    tweet_clean = clean_tweets_emoji(fila['Tweet'])
    tweet_clean = clean_tweets_regex(tweet_clean)
    if fila['Sentimiento'] == 'pos':
        rasgosPositivos.append((construirBolsaDePalabras(tweet_clean),fila['Sentimiento']))
    elif fila['Sentimiento'] == 'neu':
        rasgosNeutrales.append((construirBolsaDePalabras(tweet_clean),fila['Sentimiento']))
    else:
        rasgosNegativos.append((construirBolsaDePalabras(tweet_clean),fila['Sentimiento']))

# %%
len(rasgosPositivos)
# Out:
# 454

# %%
rasgosPositivos[5]
# Out:
# ({'Unetenses': 1, 'protegen': 1, 'animales': 1, 'crisis': 1}, 'pos')

# %%
divP=int(len(rasgosPositivos)*0.95)
divNeu=int(len(rasgosNeutrales)*0.95)
divNeg=int(len(rasgosNegativos)*0.95)
clasificadorSentimiento=NaiveBayesClassifier.train(rasgosPositivos[:divP]+rasgosNegativos[:divNeg]+rasgosNeutrales[:divNeu])

# %%
nltk.classify.util.accuracy(clasificadorSentimiento,rasgosPositivos[:divP]+rasgosNegativos[:divNeg]+rasgosNeutrales[:divNeu])
# Out:
# 0.9412219644238206

# %%
nltk.classify.util.accuracy(clasificadorSentimiento,rasgosPositivos[divP:]+rasgosNegativos[divNeg:]+rasgosNeutrales[divNeu:])
# Out:
# 0.7101449275362319

# %%
clasificadorSentimiento.show_most_informative_features()
# Out:
# Most Informative Features
#                     UCLA = 1                 neg : neu    =     17.0 : 1.0
#              Autoridades = 1                 neg : pos    =     15.7 : 1.0
#                   invita = 1                 pos : neg    =     14.3 : 1.0
#                   Sabado = 1                 neu : pos    =     11.7 : 1.0
#                situacion = 1                 neg : neu    =     11.0 : 1.0
#                 Ciencias = 1                 neg : neu    =     11.0 : 1.0
#                   inicia = 1                 pos : neg    =     10.3 : 1.0
#                  Pruebas = 1                 neu : neg    =     10.3 : 1.0
#                Venezuela = 1                 neg : pos    =     10.1 : 1.0
#                     toda = 1                 neu : neg    =      9.0 : 1.0

# %%
tweet = "Hoy se lanza mi nuevo curso de introducción al lenguaje C! y además en un par de día se lanza mi nuevo curso de Creación de Videojuegos 3D con Unity!"

print(tweet)
tweet_clean = clean_tweets_emoji(tweet)
tweet_clean = clean_tweets_regex(tweet_clean)
bolsa=construirBolsaDePalabras(tweet_clean)
print(bolsa)
# Out:
# Hoy se lanza mi nuevo curso de introducción al lenguaje C! y además en un par de día se lanza mi nuevo curso de Creación de Videojuegos 3D con Unity!
# {'Hoy': 1, 'lanza': 1, 'nuevo': 1, 'curso': 1, 'introduccion': 1, 'lenguaje': 1, 'C': 1, 'ademas': 1, 'par': 1, 'dia': 1, 'Creacion': 1, 'Videojuegos': 1, '3D': 1, 'Unity': 1}

# %%
clasificadorSentimiento.classify(bolsa)
# Out:
# 'neu'

# %%
datos_csv = pd.read_csv('CNNEE.csv')
datos_csv
# Out:
#             Date     Day                                              Tweet  \
# 0   Jun 17 2020   Jun 17  #AMLO dice que se entera de la existencia de l...
# 1   Jun 17 2020   Jun 17  ¿Cómo reaccionaría Estados Unidos si el Gobier...
# 2   Jun 17 2020   Jun 17  Es el momento perfecto para elegir un nuevo ca...
# 3   Jun 17 2020   Jun 17  "Por supuesto que no": eso respondió Fauci cua...
# 4   Jun 17 2020   Jun 17  El gobierno federal de EE.UU. quedó con 63 mil...
# 5   Jun 17 2020   Jun 17  Brasil reporta 32.188 casos nuevos de covid-19...
# 6   Jun 17 2020   Jun 17  RT @cnncolombia: Carlos Lehder, considerado co...
# 7   Jun 17 2020   Jun 17  La OMS asegura que 11 vacunas contra el #coron...
# 8   Jun 17 2020   Jun 17  ⚠️ Perú supera a Italia en número de casos con...
# 9   Jun 17 2020   Jun 17  "No se muevan. No se muevan. Solo relájense. N...
# 10  Jun 17 2020   Jun 17  Según el extracto publicado en el diario, desp...
# 11  Jun 17 2020   Jun 17  ¿Qué dicen ambos países sobre el incidente? ¿C...
# 12  Jun 17 2020   Jun 17  El gobernador de Nueva York, Andrew Coumo, des...
# 13  Jun 17 2020   Jun 17  La 23 veces campeona de torneos de Grand Slam ...
# 14  Jun 17 2020   Jun 17  AMLO aseguró que que se enteró de la existenci...
# 15  Jun 17 2020   Jun 17  Tenemos que ser el cambio de EE.UU., dice mani...
# 16  Jun 17 2020   Jun 17  ¿Recuerdas a Spot, el perro robot que ha sido ...
# 17  Jun 17 2020   Jun 17  No sé cuando voy a poder regresar a mi país, d...
# 18  Jun 17 2020   Jun 17  RT @deportescnn: Estos son los detalles del fo...
# 19  Jun 17 2020   Jun 17  🎧 #Podcast • ¿Es la dexametasuna una esperanza...
# 20  Jun 17 2020   Jun 17  La evolución del racismo a veces es sutil, per...
# 21  Jun 17 2020   Jun 17  Ministerio de Justicia presenta denuncia penal...
# 22  Jun 17 2020   Jun 17  El exasesor de seguridad nacional John Bolton ...
# 23  Jun 17 2020   Jun 17  ¿Esperabas la nueva temporada de Fortnite? Ya ...
# 24  Jun 17 2020   Jun 17  La NASA lo rechazó en 11 ocasiones. Sin embarg...
# 25  Jun 17 2020   Jun 17  El dominicano Manny Cruz le cuenta a @MarielaC...
# 26  Jun 17 2020   Jun 17  ¿Cómo se manifiesta el racismo en América Lati...
# 27  Jun 17 2020   Jun 17  Fiscalía dice que el exagente Rolfe pateó a Ra...
# 28  Jun 17 2020   Jun 17  Un exactivista evangélico habla sobre la sesió...
# 29  Jun 17 2020   Jun 17  El fiscal explicó varias violaciones a protoco...
# 30  Jun 17 2020   Jun 17  🎧 #Podcast • Esta semana dieron a conocer los ...
# 31  Jun 17 2020   Jun 17  ÚLTIMA HORA - El fiscal de distrito del condad...
# 32  Jun 17 2020   Jun 17  Esta noche en @CamiloCNN no te pierdas la entr...
#
#     Retweets  Likes
# 0          1      2
# 1          7     12
# 2          6     15
# 3         11     45
# 4         32     52
# 5         41     56
# 6         38      0
# 7         77    120
# 8        112    175
# 9         17     40
# 10        22     56
# 11        17     49
# 12        13     30
# 13        13    116
# 14        19     64
# 15        12     84
# 16        12     32
# 17        21     44
# 18         6      0
# 19        17     29
# 20        18     41
# 21        13     41
# 22       117    155
# 23         9     29
# 24        68    247
# 25         6     19
# 26        27     48
# 27        13     33
# 28         9     30
# 29        20     45
# 30        57    102
# 31        84    264
# 32         8    100

# %%
positive = []
neutral = []
negative = []

# %%
with open('CNNEEDataTag.csv', 'w', newline='', encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Tweet","Sentimiento"])
    
    for indice_fila, fila in datos_csv.iterrows():
        print(fila[2])
        tweet_clean = clean_tweets_emoji(fila[2])
        tweet_clean = clean_tweets_regex(tweet_clean)
        bolsa=construirBolsaDePalabras(tweet_clean)
        sent = clasificadorSentimiento.classify(bolsa)
        print("\033[0;31;40m "+sent+" \033[0m")
        
        writer.writerow([fila[2],sent])
        if sent == 'pos':
            positive.append(fila[2])
        elif sent == 'neu':
            neutral.append(fila[2])
        else:
            negative.append(fila[2])
# Out:
# #AMLO dice que se entera de la existencia de la comisión para la discriminación por la polémica con @ChumelTorres ¿… https://t.co/Vcmx9Ra0Cs
#  pos
# ¿Cómo reaccionaría Estados Unidos si el Gobierno de López Obrador le vendiera gasolina a Venezuela? Compartimos el… https://t.co/gxs1WJTvdr
#  neg
# Es el momento perfecto para elegir un nuevo cargador portátil o de pared, o un cargador que pueda hacer ambas cosas… https://t.co/dFqJhdUNvf
#  neg
# "Por supuesto que no": eso respondió Fauci cuando le preguntaron si va a ir al evento de campaña de Trump… https://t.co/inQJ1wPyRY
#  pos
# ¿Cómo se manifiesta el racismo en América Latina? Dialogamos sobre el tema con el profesor de Sociología Eduardo Bo… https://t.co/Q7esUQw8KI
#  neg
# Fiscalía dice que el exagente Rolfe pateó a Rayshard Brooks "mientras estaba en el suelo, mientras estaba allí luch… https://t.co/P1LaXmHGPi
#  pos
# Un exactivista evangélico habla sobre la sesión fotográfica del presidente Trump después de que la policía expulsar… https://t.co/PWPsMkQQ6b
#  neg
# El fiscal explicó varias violaciones a protocolos y reglas de la ciudad, incluyendo que una de las balas impactó ve… https://t.co/Z9rNgRQiG4
#  neg
# 🎧 #Podcast • Esta semana dieron a conocer los resultados preliminares de un estudio, aún no publicado, que indica q… https://t.co/LioYnVmPCr
#  neu
# ÚLTIMA HORA - El fiscal de distrito del condado de Fulton, Paul Howard, anunció 11 cargos contra el exagente de Atl… https://t.co/FtUVWJ2kj1
#  neu
# Esta noche en @CamiloCNN no te pierdas la entrevista con la reconocida cantante y actriz mexicana Angélica María. 9… https://t.co/YSXSRwQdFk
#  neg

# %% [markdown]
# ## Step 5: Show Data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fig = plt.figure(u'Gráfica de barras')
ax = fig.add_subplot(111)

nombres = ['Positive','Neutral','Negative']
datos = [len(positive),len(neutral),len(negative)]
xx = range(len(datos))

ax.bar(xx, datos, width=0.8, align='center')
ax.set_xticks(xx)
ax.set_xticklabels(nombres)

plt.show()

# %% [markdown]
# ### Bonus

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42).generate(tweets_clean)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("WWCode DataPY2019")
plt.show()

# %% [markdown]
# # English

# %% [markdown]
# ## Step 1: Extract Data

# %%
timeline = api.user_timeline(id="elonmusk", count=50 )

with open('elonmusk.csv', 'w', newline='', encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Date", "Day", "Tweet", "Retweets", "Likes"])
    
    for tweet in timeline:
        print(tweet.text)
        data = [tweet.created_at.date().strftime("%b %d %Y "), tweet.created_at.date().strftime("%b %d"), tweet.text, tweet.retweet_count, tweet.favorite_count]
        writer.writerow(data)
# Out:
# RT @tegmark: Help us find an unsung hero! If they win, they get $50k &amp; you get up to $3k for nominating/spreading the word. Our first 3 awa…
# @NYYScoreKeep Not sure. They’re pretty close together.
# @westcoastbill It will be real
# @cisoml @Erdayastronaut @russ_parrish Maybe Incat https://t.co/qHbJcMocFg
# @flcnhvy There will be many test flights before commercial passengers are carried. First Earth to Earth test flight… https://t.co/gKyeCVkLeQ
# @Erdayastronaut @russ_parrish We need to be far enough away so as not to bother heavily populated areas. The launch… https://t.co/UHZT7HfVsh
# @YarLP Directionally correct, but Zenit is an order of magnitude smaller than Starship system &amp; doesn’t come back &amp; land
# @21aeax US law requires at least a green card to be hired at SpaceX, as rockets are considered advanced weapons technology
# @russ_parrish Pretty much
# @AgoleiD Illuminaughty haha
# SpaceX is building floating, superheavy-class spaceports for Mars, moon &amp; hypersonic travel around Earth https://t.co/zLJjz43hKw
# @LabPadre Maybe some Flextape
# @LabPadre No problem, we can buff it out
# @Teslarati Fairing reuse is looking good
# @physorg_com @ubcnews @AAS_Publishing So where are the aliens?
# @Teslarati Or Y
# 37  Jun 11 2020   Jun 11  @mcot2222 @olenamuliarchuk @mrkylefield @clean...
# 38  Jun 11 2020   Jun 11  @justpaulinelol @engineers_feed As foretold by...
# 39  Jun 11 2020   Jun 11                             @engineers_feed Stonks
# 40  Jun 11 2020   Jun 11                                                lol
# 41  Jun 11 2020   Jun 11  @Erdayastronaut @i_gvf @SciGuySpace Exactly. C...
# 42  Jun 11 2020   Jun 11  @tobyliiiiiiiiii @physorg_com @nature @SciRepo...
# 43  Jun 11 2020   Jun 11  @olenamuliarchuk @mrkylefield @cleantechnica B...
# 44  Jun 11 2020   Jun 11  @physorg_com @nature @SciReports I thought thi...
# 45  Jun 11 2020   Jun 11  @blue_bnd @olenamuliarchuk @PPathole @mrkylefi...
# 46  Jun 11 2020   Jun 11  @PPathole @mrkylefield @cleantechnica I got th...
# 47  Jun 11 2020   Jun 11  @rhodanazanin1 @ABC7 @NBCLA @CBSLA It’s gettin...
# 48  Jun 11 2020   Jun 11  @mrkylefield @cleantechnica Exactly, fuel cell...
# 49  Jun 11 2020   Jun 11  @realAnishPai Renewable energy passed coal in ...
#
#     Retweets   Likes
# 0        444       0
# 1         32     980
# 2        369    7841
# 3         29     751
# 4        356    4678
# 5        158    3006
# 6         84    2217
# 7         76    1182
# 8         72    2444
# 9        547    7046
# 10      9254   76594
# 11       196    4049
# 12       380   16691
# 13       208    5954
# 14      4030   50883
# 15        90    2815
# 16       265    8551
# 17        38    1121
# 18       168    6004
# 19       292    2712
# 20        39    1471
# 21      1307   36703
# 22      7533   88369
# 23        65    1652
# 24      1303   18399
# 25       147    4869
# 26        44    1557
# 27       333    4327
# 28        88    2391
# 29        62    1883
# 30       106    1499
# 31        30     667
# 32        54    1419
# 33       196    2168
# 34      1391   28353
# 35     10819       0
# 36       221    9843
# 37        48    1485
# 38       334   12183
# 39      5194   59915
# 40     67896  559978
# 41       187    3025
# 42        35    1397
# 43        88    1127
# 44       142    4971
# 45        51    1188
# 46        63    1386
# 47       128    1671
# 48       370    6649
# 49       187    2422

# %%
popularity_list = []
num_list = []
num = 1

for tweet in csv_data['Tweet']:
    print(tweet)
    
    analysis = TextBlob(tweet)
    analysis = analysis.sentiment
    print(analysis)
    popularity = analysis.polarity
    popularity_list.append(popularity)
    num_list.append(num)
    num = num + 1
# Out:
# RT @tegmark: Help us find an unsung hero! If they win, they get $50k &amp; you get up to $3k for nominating/spreading the word. Our first 3 awa…
# Sentiment(polarity=0.525, subjectivity=0.3666666666666667)
# @NYYScoreKeep Not sure. They’re pretty close together.
# Sentiment(polarity=0.0, subjectivity=0.9444444444444444)
# @westcoastbill It will be real
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# @cisoml @Erdayastronaut @russ_parrish Maybe Incat https://t.co/qHbJcMocFg
# Sentiment(polarity=0.0, subjectivity=0.0)
# @flcnhvy There will be many test flights before commercial passengers are carried. First Earth to Earth test flight… https://t.co/gKyeCVkLeQ
# Sentiment(polarity=0.25, subjectivity=0.27777777777777773)
# @Erdayastronaut @russ_parrish We need to be far enough away so as not to bother heavily populated areas. The launch… https://t.co/UHZT7HfVsh
# Sentiment(polarity=-0.03333333333333333, subjectivity=0.6666666666666666)
# @YarLP Directionally correct, but Zenit is an order of magnitude smaller than Starship system &amp; doesn’t come back &amp; land
# Sentiment(polarity=0.0, subjectivity=0.25)
# @21aeax US law requires at least a green card to be hired at SpaceX, as rockets are considered advanced weapons technology
# Sentiment(polarity=-0.033333333333333326, subjectivity=0.4333333333333333)
# @russ_parrish Pretty much
# Sentiment(polarity=0.225, subjectivity=0.6)
# @AgoleiD Illuminaughty haha
# Sentiment(polarity=0.2, subjectivity=0.3)
# SpaceX is building floating, superheavy-class spaceports for Mars, moon &amp; hypersonic travel around Earth https://t.co/zLJjz43hKw
# Sentiment(polarity=0.0, subjectivity=0.0)
# @LabPadre Maybe some Flextape
# Sentiment(polarity=0.0, subjectivity=0.0)
# @LabPadre No problem, we can buff it out
# Sentiment(polarity=0.0, subjectivity=0.0)
# @Teslarati Fairing reuse is looking good
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# @physorg_com @ubcnews @AAS_Publishing So where are the aliens?
# Sentiment(polarity=0.0, subjectivity=0.0)
# @Teslarati Or Y
# Sentiment(polarity=0.0, subjectivity=0.0)
# @Teslarati No larger pack Model 3 is in development
# Sentiment(polarity=0.0, subjectivity=0.5)
# @tesla_peter @t0mmyr Actually, we’ve made slight changes, but the range improvement is &gt;90% efficiency
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.13333333333333333)
# @cleantechnica Cool
# Sentiment(polarity=0.35, subjectivity=0.65)
# @ZJasko Physics doesn’t care about politicians
# Sentiment(polarity=0.0, subjectivity=0.0)
# @jgold310 Coming soon
# Sentiment(polarity=0.0, subjectivity=0.0)
# All Model S cars made since late Jan have 402 mile range. This is just making it official.
# Sentiment(polarity=-0.3, subjectivity=0.6)
# Tesla Model S now first ever electric vehicle to receive EPA range rating above 400 miles! https://t.co/EOTwVfvHS5
# Sentiment(polarity=0.125, subjectivity=0.21666666666666667)
# @flcnhvy Absolutely
# Sentiment(polarity=0.2, subjectivity=0.9)
# China &amp; Asia Pacific Supercharger usage above pre-covid highs. North America catching up fast. Europe slightly behi… https://t.co/i82M4iSkWZ
# Sentiment(polarity=0.15833333333333335, subjectivity=0.4416666666666667)
# @VitalVegas Looking likely
# Sentiment(polarity=0.0, subjectivity=1.0)
# @Mad_Maelstrom @Peter_J_Beck @torybruno @Starlinksat223 @Erdayastronaut Throttling is done by adjusting flow to the… https://t.co/3BO9SBL3po
# Sentiment(polarity=0.0, subjectivity=0.0)
# @SciGuySpace Tank didn’t burst, but leaked at 7.6 bar. This is a good result &amp; supports idea of 304L stainless bein… https://t.co/iTUXx0HI6U
# Sentiment(polarity=0.44999999999999996, subjectivity=0.4)
# @Peter_J_Beck @torybruno @Starlinksat223 @Erdayastronaut Yeah. Merlin, using a single pintle injector with cold, li… https://t.co/2oMLALe4PQ
# Sentiment(polarity=-0.3357142857142857, subjectivity=0.6071428571428571)
# @tobyliiiiiiiiii @SciGuySpace Yes
# Sentiment(polarity=0.0, subjectivity=0.0)
# @SciGuySpace That’s the goal. There a few known weak points on this test tank, probably capable of more pressure. T… https://t.co/xme3hilQTA
# Sentiment(polarity=0.031250000000000014, subjectivity=0.40625)
# @skysira @joshcohen @tokren1 @Andrew81947993 @FatEmperor @MarkChangizi @gordon_dyce @dvdclstn @Not_Far_Enough… https://t.co/iCR5yE3cQr
# Sentiment(polarity=0.0, subjectivity=0.0)
# @vlives23 @LoopedBuffalo @Michaelnardone4 @FutureJurvetson @SpaceXStarlink @SpaceX Sure
# Sentiment(polarity=0.5, subjectivity=0.8888888888888888)
# @Michaelnardone4 @FutureJurvetson @SpaceXStarlink @SpaceX Around 20ms. It’s designed to run real-time, competitive… https://t.co/1oJIQJGp1s
# Sentiment(polarity=0.0, subjectivity=0.0)
# @FutureJurvetson @SpaceXStarlink @SpaceX It will get even simpler. Just two instructions for Starlink: plug in &amp; po… https://t.co/54NBGGcYCb
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @SpaceX: Falcon 9 launches 58 Starlink satellites and 3 @planetlabs Skysats to orbit before returning to Earth and landing on a droneshi…
# Sentiment(polarity=0.0, subjectivity=0.0)
# @JimBridenstine @NASA Congratulations Kathy!
# Sentiment(polarity=0.0, subjectivity=0.0)
# @mcot2222 @olenamuliarchuk @mrkylefield @cleantechnica Acceptable, if your drivetrain is very efficient &amp; you add a little manga
# Sentiment(polarity=0.0062500000000000056, subjectivity=0.4)
# @justpaulinelol @engineers_feed As foretold by https://t.co/LJJCD7BAgX
# Sentiment(polarity=0.0, subjectivity=0.0)
# @engineers_feed Stonks
# Sentiment(polarity=0.0, subjectivity=0.0)
# lol
# Sentiment(polarity=0.8, subjectivity=0.7)
# @Erdayastronaut @i_gvf @SciGuySpace Exactly. Chartering a dedicated 747 flight around the world costs less than buy… https://t.co/61lRA0YF5v
# Sentiment(polarity=0.04166666666666667, subjectivity=0.15833333333333333)
# @tobyliiiiiiiiii @physorg_com @nature @SciReports True
# Sentiment(polarity=0.35, subjectivity=0.65)
# @olenamuliarchuk @mrkylefield @cleantechnica Battery industry is world champion at bs. “Lithium-ion” doesn’t really… https://t.co/x1KaxmHixK
# Sentiment(polarity=0.0, subjectivity=0.0)
# @physorg_com @nature @SciReports I thought this was an Onion article
# Sentiment(polarity=0.0, subjectivity=0.0)
# @blue_bnd @olenamuliarchuk @PPathole @mrkylefield @cleantechnica Staggeringly dumb
# Sentiment(polarity=-0.375, subjectivity=0.5)
# @PPathole @mrkylefield @cleantechnica I got the fuel cell question about 8000 times
# Sentiment(polarity=0.0, subjectivity=0.0)
# @rhodanazanin1 @ABC7 @NBCLA @CBSLA It’s getting Biblical
# Sentiment(polarity=0.0, subjectivity=0.0)
# @mrkylefield @cleantechnica Exactly, fuel cells = fool sells
# Sentiment(polarity=0.25, subjectivity=0.25)
# @realAnishPai Renewable energy passed coal in April https://t.co/1kRCyGXfN9
# Sentiment(polarity=0.0, subjectivity=0.0)

# %% [markdown]
# ## Step 3: ShowData

# %%
plt.figure(figsize=(20,10))
plt.scatter(num_list, popularity_list)
#plt.scatter(excel_data['Day'], popularity_list)
plt.title("Sentiments analysis to PyConCo2020")
plt.xlabel("# tweet")
plt.ylabel("Sentiment")
plt.show()
